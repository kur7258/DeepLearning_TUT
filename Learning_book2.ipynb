# %%
import mglearn
import matplotlib.pyplot as plt

# %%
X, y = mglearn.datasets.make_forge()

# %%
mglearn.discrete_scatter(X[:, 0], X[:, 1], y)
plt.legend(['Class 0', 'Class 1'], loc=4)
plt.xlabel('First attribute')
plt.ylabel("Second attribute")
print('X.shape : {}'.format(X.shape))
# Out:
# X.shape : (26, 2)

# %%
X, y = mglearn.datasets.make_wave(n_samples=40)
plt.plot(X, y, 'o')
plt.ylim(-3, 3)
plt.xlabel('Attribute')
plt.ylabel('Target')
# Out:
# Text(0, 0.5, 'Target')

# %%
from sklearn.datasets import load_breast_cancer
import numpy as np

# %%
cancer = load_breast_cancer()
print('Cancer.keys() : \n{}'.format(cancer.keys()))
# Out:
# Cancer.keys() :
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
print('Shape of breast cancer data : {}'.format(cancer.data.shape))
# Out:
# Shape of breast cancer data : (569, 30)

# %%
print('Number of sample per class : \n{}'.format(
{n: v for n, v in zip(cancer.target_names, np.bincount(cancer.target))}))
# Out:
# Number of sample per class :
# {'malignant': 212, 'benign': 357}

# %%
mglearn.plots.plot_knn_classification(n_neighbors=3)
# Out:
# /home/kur/anaconda3/lib/python3.8/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function make_blobs is deprecated; Please import make_blobs directly from scikit-learn
#   warnings.warn(msg, category=FutureWarning)
